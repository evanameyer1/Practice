# %%
import pandas as pd
import re
from re import match
import requests
from bs4 import BeautifulSoup as soup
import difflib
import math

# %%
study_groups = pd.read_csv("dummy_data_sets/study_groups.csv")

# %%
study_groups.head()
# Out:
#              Timestamp UIC Email 📧\nEg. Rchen64@uic.edu  \
# 0  12/23/2022 23:35:27     rickyyoungtutoring@gmail.com
# 1   1/25/2023 21:47:16                     avas@uic.edu
# 2   1/26/2023 13:32:01                   carri2@uic.edu
# 3   1/26/2023 13:33:05                 Smadan7@uic.edu
# 4   1/26/2023 13:33:55                   sahma6@uic.edu
#
#   What course do you want to study for?\nEg. CHEM 101\nList additional courses separately using the course options below (not required).   \
# 0                                           Chem 444
# 1                                           CHEM 314
# 2                                           MGMT 340
# 3    Business intelligence and marketing technology
# 4                                           BIOS 352
#
#   Course 2\n Course 3\n Course 4\n Course 5\n  \
# 0        NaN        NaN        NaN        NaN
# 1   BIOS 220        NaN        NaN        NaN
# 2   ENTR 310     BA 220    IDS 355    IDS 200
# 3        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN
#
#   Please select the residence hall you live in or the commuter option. 🏡  \
# 0                                           Commuter
# 1                                James Stukel Towers
# 2                                James Stukel Towers
# 3                                Thomas Beckham Hall
# 4                   Academic and Residential Complex
#
#   When studying with other people, I usually act as a(n)________  \
# 0                                            Teacher
# 1                                         Note-taker
# 2                                           Listener
# 3                                        Facilitator
# 4                                           Listener
#
#                       I’m more of a ______ learner.
# 0  Visual (I understand and remember material mai...
# 1  Hands-on (I prefer to touch, move, build, or d...
# 2  Hands-on (I prefer to touch, move, build, or d...
# 3  Hands-on (I prefer to touch, move, build, or d...
# 4  Visual (I understand and remember material mai...

# %%
study_groups.columns
# Out:
# Index(['Timestamp', 'UIC Email 📧\nEg. Rchen64@uic.edu',
#        'What course do you want to study for?\nEg. CHEM 101\nList additional courses separately using the course options below (not required). ',
#        'Course 2\n', 'Course 3\n', 'Course 4\n', 'Course 5\n',
#        'Please select the residence hall you live in or the commuter option. 🏡',
#        'When studying with other people, I usually act as a(n)________',
#        'I’m more of a ______ learner. '],
#       dtype='object')

# %%
study_groups.rename(columns={'UIC Email 📧\nEg. Rchen64@uic.edu':'email', 'What course do you want to study for?\nEg. CHEM 101\nList additional courses separately using the course options below (not required). ':
                            'course_1', 'Course 2\n':'course_2', 'Course 3\n':'course_3', 'Course 4\n':'course_4', 'Course 5\n':'course_5', 'Please select the residence hall you live in or the commuter option. 🏡':'dorm', 
                            'When studying with other people, I usually act as a(n)________':'desired_role', 'I’m more of a ______ learner. ':'desired_learner'}, inplace=True)

# %%
study_groups.drop(columns=['Timestamp'], inplace=True)

# %%
study_groups['email'] = [row.lower() for row in study_groups['email']]

# %%
for col in study_groups[['course_1', 'course_2', 'course_3', 'course_4', 'course_5']]:
    study_groups[str(col)].fillna('NONE', inplace=True)
    study_groups[str(col)] = [row.upper() for row in study_groups[str(col)]]

# %%
study_groups = study_groups[study_groups['email'].str.contains('\w*@uic.edu')]

# %%
study_groups
# Out:
#                 email                                         course_1  \
# 1        avas@uic.edu                                         CHEM 314
# 2      carri2@uic.edu                                         MGMT 340
# 3    smadan7@uic.edu   BUSINESS INTELLIGENCE AND MARKETING TECHNOLOGY
# 4      sahma6@uic.edu                                         BIOS 352
# 5      abang4@uic.edu                                         ECON 120
# ..                ...                                              ...
# 95    ehamma3@uic.edu                                     CHEM 124-125
# 96    ichoha4@uic.edu                                        ACTG 210
# 97  cthoma60@uic.edu                                           BIO 286
# 98     osanu2@uic.edu                                         CHEM 122
# 99     schat6@uic.edu                                         CHEM 124
#
#     course_2             course_3          course_4 course_5  \
# 1   BIOS 220                 NONE              NONE     NONE
# 2   ENTR 310               BA 220           IDS 355  IDS 200
# 3       NONE                 NONE              NONE     NONE
# 4       NONE                 NONE              NONE     NONE
# 5   MATH 165  HUMAN NUTRITION 196              NONE     NONE
# ..       ...                  ...               ...      ...
# 95  ECON 121          PHYSICS 131              NONE     NONE
# 96   IDS 270              IDS 331           FIN 300  MUS 118
# 97      NONE                 NONE              NONE     NONE
# 98  CHEM 123             BIOS 110  ANTHROPOLOGY 100     NONE
# 99  MATH 180             ACTG 210              NONE     NONE
#
#                                 dorm desired_role  \
# 1                James Stukel Towers   Note-taker
# 2                James Stukel Towers     Listener
# 3                Thomas Beckham Hall  Facilitator
# 4   Academic and Residential Complex     Listener
# 5   Academic and Residential Complex     Listener
# ..                               ...          ...
# 95               James Stukel Towers  Facilitator
# 96               Thomas Beckham Hall     Listener
# 97               Thomas Beckham Hall     Listener
# 98                         Courtyard   Note-taker
# 99               James Stukel Towers   Note-taker
#
#                                       desired_learner
# 1   Hands-on (I prefer to touch, move, build, or d...
# 2   Hands-on (I prefer to touch, move, build, or d...
# 3   Hands-on (I prefer to touch, move, build, or d...
# 4   Visual (I understand and remember material mai...
# 5   Reading and Writing (I find writing, reading a...
# ..                                                ...
# 95  Visual (I understand and remember material mai...
# 96  Visual (I understand and remember material mai...
# 97  Visual (I understand and remember material mai...
# 98  Auditory (I learn most effectively by listenin...
# 99  Visual (I understand and remember material mai...
#
# [97 rows x 9 columns]

# %%
html = soup(requests.get(f'https://catalog.uic.edu/ucat/course-descriptions/').content, 'html.parser')

# %%
table = html.find('div', attrs = {'class':'sitemap'})

# %%
classes = {}
for row in table.find_all('a'):
    classes[row.string.split('(')[0].upper().strip()] = row.string.split('(')[-1].split(')')[0]

# %%
classes
# Out:
# {'ACADEMIC SKILLS PROGRAM': 'ASP',
#  'ACCOUNTING': 'ACTG',
#  'ANATOMY AND CELL BIOLOGY': 'ANAT',
#  'ANTHROPOLOGY': 'ANTH',
#  'APPLIED HEALTH SCIENCES': 'AHS',
#  'ARABIC': 'ARAB',
#  'ARCHITECTURE': 'ARCH',
#  'ART': 'ART',
#  'ART HISTORY': 'AH',
#  'BIOCHEMISTRY AND MOLECULAR GENETICS': 'BCMG',
#  'BIOLOGICAL SCIENCES': 'BIOS',
#  'BIOMEDICAL AND HEALTH INFORMATION SCIENCES': 'BHIS',
#  'BIOMEDICAL ENGINEERING': 'BME',
#  'BIOPHARMACEUTICAL SCIENCES': 'BPS',
#  'BIOSTATISTICS': 'BSTT',
#  'BLACK STUDIES': 'BLST',
#  'BUSINESS ADMINISTRATION': 'BA',
#  'CAMPUS COURSES': 'CC',
#  'CATHOLIC STUDIES': 'CST',
#  'CENTRAL AND EASTERN EUROPEAN STUDIES': 'CEES',
#  'CHEMICAL ENGINEERING': 'CHE',
#  'CHEMISTRY': 'CHEM',
#  'CHINESE': 'CHIN',
#  'CIVIL, MATERIALS, AND ENVIRONMENTAL ENGINEERING': 'CME',
#  'CLASSICS': 'CL',
#  'COMMUNICATION': 'COMM',
#  'COMMUNITY HEALTH SCIENCES': 'CHSC',
#  'COMPUTER SCIENCE': 'CS',
#  'CRIMINOLOGY, LAW, AND JUSTICE': 'CLJ',
#  'CURRICULUM AND INSTRUCTION': 'CI',
#  'DESIGN': 'DES',
#  'DIALOGUE': 'DLG',
#  'DISABILITY AND HUMAN DEVELOPMENT': 'DHD',
#  'EARTH AND ENVIRONMENTAL SCIENCES': 'EAES',
#  'ECONOMICS': 'ECON',
#  'EDUCATION': 'ED',
#  'EDUCATIONAL POLICY STUDIES': 'EDPS',
#  'EDUCATIONAL PSYCHOLOGY': 'EPSY',
#  'ELECTRICAL AND COMPUTER ENGINEERING': 'ECE',
#  'ENGINEERING': 'ENGR',
#  'ENGLISH': 'ENGL',
#  'ENGLISH LANGUAGE AND SUPPORT FOR INTERNATIONALS': 'ELSI',
#  'ENTREPRENEURSHIP': 'ENTR',
#  'FINANCE': 'FIN',
#  'FRENCH': 'FR',
#  "GENDER AND WOMEN'S STUDIES": 'GWS',
#  'GEOGRAPHY': 'GEOG',
#  'GERMANIC STUDIES': 'GER',
#  'GLOBAL ASIAN STUDIES': 'GLAS',
#  'GREEK, ANCIENT': 'GKA',
#  'GREEK, MODERN': 'GKM',
#  'GUARANTEED ADMISSIONS MEDICINE': 'GAMD',
#  'HEALTH INFORMATION MANAGEMENT': 'HIM',
#  'HEBREW': 'HEB',
#  'HINDI-URDU': 'HNUR',
#  'HISTORY': 'HIST',
#  'HONORS COLLEGE COURSES': 'HON',
#  'HUMAN NUTRITION': 'HN',
#  'HUMANITIES': 'HUM',
#  'INDUSTRIAL ENGINEERING': 'IE',
#  'INFORMATION AND DECISION SCIENCES': 'IDS',
#  'INFORMATION TECHNOLOGY': 'IT',
#  'INTERDISCIPLINARY EDUCATION IN THE ARTS': 'IDEA',
#  'INTERDISCIPLINARY PUBLIC HEALTH SCIENCES': 'IPHS',
#  'INTERDISCIPLINARY STUDIES IN THE ARTS': 'ISA',
#  'INTERNATIONAL STUDIES': 'INST',
#  'ITALIAN': 'ITAL',
#  'JAPANESE': 'JPN',
#  'JEWISH STUDIES': 'JST',
#  'KINESIOLOGY': 'KN',
#  'KOREAN': 'KOR',
#  'LATIN': 'LAT',
#  'LATIN AMERICAN AND LATINO STUDIES': 'LALS',
#  'LIBERAL ARTS AND SCIENCES': 'LAS',
#  'LIBRARY AND INFORMATION SCIENCE': 'LIB',
#  'LINGUISTICS': 'LING',
#  'LITERATURES, CULTURAL STUDIES, AND LINGUISTICS': 'LCSL',
#  'LITHUANIAN': 'LITH',
#  'MANAGEMENT': 'MGMT',
#  'MARKETING': 'MKTG',
#  'MASTER OF ENGINEERING': 'MENG',
#  'MATHEMATICAL COMPUTER SCIENCE': 'MCS',
#  'MATHEMATICS': 'MATH',
#  'MATHEMATICS TEACHING': 'MTHT',
#  'MECHANICAL ENGINEERING': 'ME',
#  'MEDICINAL CHEMISTRY AND PHARMACOGNOSY': 'PMMP',
#  'MICROBIOLOGY AND IMMUNOLOGY': 'MIM',
#  'MILITARY SCIENCE': 'MILS',
#  'MOVING IMAGE ARTS': 'MOVI',
#  'MUSEUM AND EXHIBITION STUDIES': 'MUSE',
#  'MUSIC': 'MUS',
#  'NATIVE AMERICAN STUDIES': 'NAST',
#  'NATURAL SCIENCES': 'NATS',
#  'NAVAL SCIENCE': 'NS',
#  'NEUROSCIENCE': 'NEUS',
#  'NURSING CORE': 'NURS',
#  'NURSING ELECTIVE': 'NUEL',
#  'OCCUPATIONAL THERAPY': 'OT',
#  'PATHOLOGY': 'PATH',
#  'PHARMACEUTICAL SCIENCES': 'PSCI',
#  'PHARMACOLOGY': 'PCOL',
#  'PHARMACY': 'PHAR',
#  'PHARMACY PRACTICE': 'PMPR',
#  'PHARMACY SYSTEMS, OUTCOMES, AND POLICY': 'PSOP',
#  'PHILOSOPHY': 'PHIL',
#  'PHYSICAL THERAPY': 'PT',
#  'PHYSICS': 'PHYS',
#  'PHYSIOLOGY AND BIOPHYSICS': 'PHYB',
#  'POLISH': 'POL',
#  'POLITICAL SCIENCE': 'POLS',
#  'PORTUGUESE': 'PORT',
#  'PSYCHOLOGY': 'PSCH',
#  'PUBLIC ADMINISTRATION': 'PA',
#  'PUBLIC HEALTH': 'PUBH',
#  'PUBLIC POLICY': 'PPOL',
#  'PUBLIC POLICY ANALYSIS': 'PPA',
#  'REAL ESTATE STUDIES': 'RES',
#  'RELIGIOUS STUDIES': 'RELS',
#  'RUSSIAN': 'RUSS',
#  'SLAVIC AND BALTIC LANGUAGES AND LITERATURES': 'SLAV',
#  'SOCIAL JUSTICE': 'SJ',
#  'SOCIOLOGY': 'SOC',
#  'SPANISH': 'SPAN',
#  'SPECIAL EDUCATION': 'SPED',
#  'STATISTICS': 'STAT',
#  'STUDY ABROAD': 'SABR',
#  'THEATRE': 'THTR',
#  'URBAN AND PUBLIC AFFAIRS': 'UPA',
#  'URBAN PLANNING AND POLICY': 'UPP',
#  'URBAN STUDIES': 'US'}

# %%
study_groups.replace('PSCH', 'PSCH 100', inplace=True)

# %%
difflib.get_close_matches('MTH', classes.values())
# Out:
# ['MTHT', 'MATH']

# %%
def class_list_fix():
    class_list = []
    for i in range(1,6):
        for course in study_groups[f"course_{i}"]:
            class_list.append(course)
    return(class_list)

# %%
def patch_class_names(column):
    class_list = class_list_fix()
    for row in study_groups[column]:
        if row == 'NONE':
            pass
        else:
            try:
                cleaned_class = re.search('[A-Z]+', row).group()
                class_num = re.search('\d+', row).group()
                if cleaned_class in classes.values():
                    study_groups.replace(row, classes[cleaned_class] + ' ' + class_num, inplace=True)
                else:
                    pass
                    study_groups.replace(row, str(difflib.get_close_matches(row, class_list)), inplace=True)
            except:
                pass

# %%
def clean_class_names(column):
    for row in study_groups[column]:
        if re.match('^[A-Z]* \d{3}$', row):
            pass
        else:
            study_groups.replace(row, 'None', inplace=True)

# %%
for i in range(1, 6):
    patch_class_names(f'course_{i}')
    clean_class_names(f'course_{i}')
    study_groups = study_groups[study_groups['course_1'] != 'None'].reset_index(drop = True)

# %%
study_groups.replace('CHEM 122123', 'CHEM 123', inplace=True)

# %%
study_groups
# Out:
#               email  course_1  course_2  course_3 course_4 course_5  \
# 0      avas@uic.edu  CHEM 314  BIOS 220      None     None     None
# 1    carri2@uic.edu  MGMT 340  ENTR 310    BA 220  IDS 355  IDS 200
# 2    sahma6@uic.edu  BIOS 352      None      None     None     None
# 3    abang4@uic.edu  ECON 120  MATH 165      None     None     None
# 4   mgree32@uic.edu  MATH 125  ACTG 210      None     None     None
# ..              ...       ...       ...       ...      ...      ...
# 69   osanu2@uic.edu  CHEM 122  CHEM 123  BIOS 110     None     None
# 70   ikuku2@uic.edu  CHEM 101      None      None     None     None
# 71  mbell37@uic.edu  PHYS 141  CHEM 234  MATH 210     None     None
# 72   osanu2@uic.edu  CHEM 122  CHEM 123  BIOS 110     None     None
# 73   schat6@uic.edu  CHEM 124  MATH 180  ACTG 210     None     None
#
#                                 dorm desired_role  \
# 0                James Stukel Towers   Note-taker
# 1                James Stukel Towers     Listener
# 2   Academic and Residential Complex     Listener
# 3   Academic and Residential Complex     Listener
# 4                James Stukel Towers   Note-taker
# ..                               ...          ...
# 69                         Courtyard     Listener
# 70                      Commons West  Facilitator
# 71               James Stukel Towers     Listener
# 72                         Courtyard   Note-taker
# 73               James Stukel Towers   Note-taker
#
#                                       desired_learner
# 0   Hands-on (I prefer to touch, move, build, or d...
# 1   Hands-on (I prefer to touch, move, build, or d...
# 2   Visual (I understand and remember material mai...
# 3   Reading and Writing (I find writing, reading a...
# 4   Hands-on (I prefer to touch, move, build, or d...
# ..                                                ...
# 69  Reading and Writing (I find writing, reading a...
# 70  Reading and Writing (I find writing, reading a...
# 71  Hands-on (I prefer to touch, move, build, or d...
# 72  Auditory (I learn most effectively by listenin...
# 73  Visual (I understand and remember material mai...
#
# [74 rows x 9 columns]

# %%
unique_classes = {}
for i in range(1, 6):
    for row in study_groups[f'course_{i}']:
        if row in unique_classes.keys():
            unique_classes[row] += 1
        else:
            unique_classes[row] = 1

# %%
unique_classes
# Out:
# {'CHEM 314': 1,
#  'MGMT 340': 3,
#  'BIOS 352': 1,
#  'ECON 120': 2,
#  'MATH 125': 2,
#  'CHEM 124': 5,
#  'MATH 110': 3,
#  'CHEM 234': 3,
#  'PSCH 262': 2,
#  'CHEM 101': 5,
#  'BIOS 110': 8,
#  'CHEM 122': 8,
#  'CS 141': 6,
#  'ACTG 210': 6,
#  'MATH 210': 6,
#  'MATH 180': 3,
#  'CHEM 232': 7,
#  'PHYS 141': 5,
#  'MATH 181': 4,
#  'IDS 410': 1,
#  'PPOL 105': 2,
#  'MCS 275': 1,
#  'PHYS 131': 1,
#  'IDS 270': 1,
#  'SPAN 102': 1,
#  'MGMT 460': 1,
#  'MUS 104': 1,
#  'MATH 165': 2,
#  'DES 209': 1,
#  'PSCH 100': 2,
#  'PPOL 330': 1,
#  'ACTG 355': 1,
#  'PHYS 112': 1,
#  'CLJ 200': 3,
#  'PHYS 441': 1,
#  'IDS 371': 1,
#  'FR 101': 1,
#  'INST 184': 1,
#  'MATH 121': 1,
#  'ARCH 372': 1,
#  'BIOS 350': 2,
#  'ACTG 474': 1,
#  'CLJ 210': 1,
#  'MATH 310': 2,
#  'BIOS 220': 3,
#  'ENTR 310': 1,
#  'None': 175,
#  'BIOS 120': 1,
#  'EAES 111': 1,
#  'ANTH 105': 2,
#  'PHYS 132': 3,
#  'MATH 220': 1,
#  'CS 151': 3,
#  'IDS 200': 3,
#  'PSCH 242': 2,
#  'PHYS 142': 1,
#  'US 101': 1,
#  'MCS 320': 2,
#  'SPAN 103': 2,
#  'MGMT 486': 1,
#  'ENGL 104': 1,
#  'MGMT 453': 2,
#  'DES 251': 1,
#  'SJ 201': 1,
#  'ACTG 470': 1,
#  'BA 200': 1,
#  'PHYS 245': 1,
#  'ANTH 101': 1,
#  'ARCH 466': 1,
#  'BIOS 222': 2,
#  'ACTG 315': 1,
#  'IE 342': 2,
#  'CHEM 123': 3,
#  'PPOL 230': 1,
#  'BA 220': 1,
#  'MATH 160': 1,
#  'PSCH 270': 2,
#  'GWS 100': 1,
#  'CME 201': 2,
#  'CS 111': 1,
#  'STAT 382': 1,
#  'MATH 300': 1,
#  'MGMT 475': 1,
#  'MUS 102': 1,
#  'AH 111': 1,
#  'ENGL 161': 1,
#  'ART 110': 1,
#  'HN 196': 1,
#  'CS 107': 1,
#  'COMM 102': 1,
#  'MATH 179': 1,
#  'IDS 355': 2,
#  'ACTG 211': 1,
#  'SOC 100': 1,
#  'PPOL 210': 1,
#  'HIST 106': 1,
#  'MGMT 463': 1,
#  'MUS 118': 1,
#  'MUS 127': 1,
#  'ECE 594': 1,
#  'BIOS 343': 1,
#  'CS 109': 1,
#  'CLJ 220': 1,
#  'ART 170': 1,
#  'ART 151': 1,
#  'US 390': 1,
#  'BIOS 310': 1,
#  'GLAS 100': 1}

# %%
def generate_groups(class_dict):
    dead_courses = {}
    groups = {}
    for course, count in class_dict.items():
        if course == 'None':
            break
        else:
            list_count = 0
            group_size = 0
            if count % 4 == 3:
                list_count = math.ceil(count / 4)
                group_size = 4
                for i in range(1, int(list_count)):
                    list_name = f'{course}_{i}'
                    globals()[list_name] = []
                    groups[list_name] = int(group_size)
                for i in range(int(list_count), int(list_count) + 1):
                    list_name = f'{course}_{i}'
                    globals()[list_name] = []
                    groups[list_name] = int(group_size) - 1
            else:
                if count % 5 == 0:
                    list_count = math.ceil(count / 5)
                    group_size = 5
                elif count % 4 == 0:
                    list_count = math.ceil(count / 4)
                    group_size = 4
                elif count % 3 == 0:
                    list_count = math.ceil(count / 3)
                    group_size = 3
                else:
                    dead_courses[course] = count

                for i in range(1, int(list_count) + 1):
                    list_name = f'{course}_{i}'
                    globals()[list_name] = []
                    groups[list_name] = int(group_size)
    return groups

# %%
groups = generate_groups(unique_classes)
groups
# Out:
# {'MGMT 340_1': 3,
#  'CHEM 124_1': 5,
#  'MATH 110_1': 3,
#  'CHEM 234_1': 3,
#  'CHEM 101_1': 5,
#  'BIOS 110_1': 4,
#  'BIOS 110_2': 4,
#  'CHEM 122_1': 4,
#  'CHEM 122_2': 4,
#  'CS 141_1': 3,
#  'CS 141_2': 3,
#  'ACTG 210_1': 3,
#  'ACTG 210_2': 3,
#  'MATH 210_1': 3,
#  'MATH 210_2': 3,
#  'MATH 180_1': 3,
#  'CHEM 232_1': 4,
#  'CHEM 232_2': 3,
#  'PHYS 141_1': 5,
#  'MATH 181_1': 4,
#  'CLJ 200_1': 3,
#  'BIOS 220_1': 3}

# %%
def match_groups(table, groups):
    final_groups = {}
    for course, count in groups.items():
        course = course.split('_')[0]
        temp_group = []
        while count > 0:
            for email in table['email']:
                if (table[table['email'] == email]['course_1'] == course).any():
                    temp_group.append(email)
                    count -= 1
                elif (table[table['email'] == email]['course_2'] == course).any():
                    temp_group.append(email)
                    count -= 1
                elif (table[table['email'] == email]['course_3'] == course).any():
                    temp_group.append(email)
                    count -= 1
                elif (table[table['email'] == email]['course_4'] == course).any():
                    temp_group.append(email)
                    count -= 1
                elif (table[table['email'] == email]['course_5'] == course).any():
                    temp_group.append(email)
                    count -= 1
                else:
                    pass
        final_groups[course] = temp_group
        print(f'{course} is done!')
    return final_groups

# %%
final_groups = match_groups(study_groups, groups)
# Out:
# MGMT 340 is done!
# CHEM 124 is done!
# MATH 110 is done!
# CHEM 234 is done!
# CHEM 101 is done!
# BIOS 110 is done!
# BIOS 110 is done!
# CHEM 122 is done!
# CHEM 122 is done!
# CS 141 is done!
# CS 141 is done!
# ACTG 210 is done!
# ACTG 210 is done!
# MATH 210 is done!
# MATH 210 is done!
# MATH 180 is done!
# CHEM 232 is done!
# CHEM 232 is done!
# PHYS 141 is done!
# MATH 181 is done!
# CLJ 200 is done!
# BIOS 220 is done!

# %%
with open("study_groups.txt", 'w') as f: 
    for course, emails in final_groups.items(): 
        f.write('%s:%s\n' % (course, emails))
